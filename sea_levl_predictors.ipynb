# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
path=r'/Users/beckyiyeh/Documents/hello_ds./epa-sea-level.csv'
df=pd.read_csv(path)
df
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %%
plt.scatter(x=df["Year"],y=df["CSIRO Adjusted Sea Level"],s=20,cmap='Reds',label='Sea level')
slope, intercept, r_value, p_value, std_err = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
x=np.arange(df['Year'].min(),2051)
line_of_best_fit = slope * x + intercept

df_2000 = df[df['Year'] >= 2000]

# Calculate line of best fit for data from 2000 onwards
slope_2000, intercept_2000, _, _, _ = linregress(df_2000['Year'], df_2000['CSIRO Adjusted Sea Level'])
y= np.arange(2000, 2051)
line_of_best_fit_2000 = slope_2000 * years_2000_extended + intercept_2000

plt.plot(x,line_of_best_fit,color='green',label='best fit')
plt.plot(y,line_of_best_fit_2000,color='red',linestyle='--', label="Best Fit Line (2000 Onwards)")

plt.legend()
plt.colorbar()
plt.xlabel("Year")
plt.ylabel("Sea Level (inches)")
plt.title("Sea Level Rise Prediction")


plt.show()
# Out:
# /var/folders/xb/0d6fwnd11lbfh6b333tqcylh0000gn/T/ipykernel_84751/3240275369.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x=df["Year"],y=df["CSIRO Adjusted Sea Level"],s=20,cmap='Reds',label='Sea level')

# %%
linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
# Out:
# LinregressResult(slope=0.06304458401213482, intercept=-119.06594196773983, rvalue=0.984757131182585, pvalue=3.7886969791130475e-102, stderr=0.0009692118713287152, intercept_stderr=1.886943381242523)
